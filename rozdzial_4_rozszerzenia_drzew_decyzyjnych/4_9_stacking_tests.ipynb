# %% [markdown]
# # 4.9 Testowanie możliwości stackingu

# %%
import pandas as pd

# %%
boston_df = pd.read_parquet("../data/boston_df.parquet")
boston_df.sample(5)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 23   0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952  4.0  307.0
# 245  0.19133  22.0   5.86   0.0  0.431  5.605   70.2  7.9549  7.0  330.0
# 18   0.80271   0.0   8.14   0.0  0.538  5.456   36.6  3.7965  4.0  307.0
# 230  0.53700   0.0   6.20   0.0  0.504  5.981   68.1  3.6715  8.0  307.0
# 494  0.27957   0.0   9.69   0.0  0.585  5.926   42.6  2.3817  6.0  391.0
#
#      PTRATIO       B  LSTAT  MEDV
# 23      21.0  394.54  19.88  14.5
# 245     19.1  389.13  18.46  18.5
# 18      21.0  288.99  11.69  20.2
# 230     17.4  378.35  11.65  24.3
# 494     19.2  396.90  13.59  24.5

# %%
X = boston_df.drop(columns="MEDV")
y = boston_df["MEDV"]

# %% [markdown]
# ## Tworzenie bazowych regresorów

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt_best_params = {
    "ccp_alpha": 0.0,
    "criterion": 'absolute_error',
    "max_depth": 7,
    "max_features": None,
    "min_samples_leaf": 8,
    "min_samples_split": 2
}
dt = DecisionTreeRegressor(**dt_best_params)

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
et = ExtraTreesRegressor(n_estimators=10, **dt_best_params)

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor(random_state=253)

# %% [markdown]
# Mamy już podstawowe drzewo decyzyjne, model Extra Trees oraz XGBoost, ponieważ to te trzy metody dały nam jak do tej pory najlepsze rezultaty. Sci-kit learn ma w swoim zanadrzu jeszcze kilka modeli regresji, które potraktujemy trochę narzędziowo i dołączymy do listy estymatorów w stackingu.

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
from sklearn.svm import SVR

# %%
svm = SVR()

# %% [markdown]
# ## Tworzenie modelu stackingu
# Jak wspomnieliśmy, stacking pozwala nam nauczyć pewne bazowe modele, a następnie wykorzystuje ich wyniki do finalnej klasyfikacji, Możemy więc przetestować różne konfiguracje, co też uczynimy.

# %%
estimators = [dt, et, xgb, lr, svm]
named_estimators = [
    ("decision_tree", dt), ("extra_trees", et), ("xgboost", xgb), ("linear_regression", lr),
    ("support_vector_machine", svm)
]

# %%
from sklearn.ensemble import StackingRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "final_estimator": estimators
}

# %%
cv = GridSearchCV(StackingRegressor(estimators=named_estimators),
                  param_grid=param_grid, n_jobs=-1, verbose=1, cv=5, scoring=["neg_mean_squared_error", "neg_mean_absolute_error"], return_train_score=True, refit="neg_mean_squared_error")
cv.fit(X, y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# GridSearchCV(cv=5,
#              estimator=StackingRegressor(estimators=[('decision_tree',
#                                                       DecisionTreeRegressor(criterion='absolute_error',
#                                                                             max_depth=7,
#                                                                             min_samples_leaf=8)),
#                                                      ('extra_trees',
#                                                       ExtraTreesRegressor(criterion='absolute_error',
#                                                                           max_depth=7,
#                                                                           max_features=None,
#                                                                           min_samples_leaf=8,
#                                                                           n_estimators=10)),
#                                                      ('xgboost',
#                                                       XGBRegressor(base_score=None,
#                                                                    booster=None,
#                                                                    callbacks=N...
#                                                           max_delta_step=None,
#                                                           max_depth=None,
#                                                           max_leaves=None,
#                                                           min_child_weight=None,
#                                                           missing=nan,
#                                                           monotone_constraints=None,
#                                                           multi_strategy=None,
#                                                           n_estimators=None,
#                                                           n_jobs=None,
#                                                           num_parallel_tree=None,
#                                                           random_state=253, ...),
#                                              LinearRegression(), SVR()]},
#              refit='neg_mean_squared_error', return_train_score=True,
#              scoring=['neg_mean_squared_error', 'neg_mean_absolute_error'],
#              verbose=1)

# %%
cv.best_estimator_, cv.best_score_
# Out:
# (StackingRegressor(estimators=[('decision_tree',
#                                 DecisionTreeRegressor(criterion='absolute_error',
#                                                       max_depth=7,
#                                                       min_samples_leaf=8)),
#                                ('extra_trees',
#                                 ExtraTreesRegressor(criterion='absolute_error',
#                                                     max_depth=7,
#                                                     max_features=None,
#                                                     min_samples_leaf=8,
#                                                     n_estimators=10)),
#                                ('xgboost',
#                                 XGBRegressor(base_score=None, booster=None,
#                                              callbacks=None,
#                                              colsample_bylevel=None,
#                                              c...
#                                              max_cat_threshold=None,
#                                              max_cat_to_onehot=None,
#                                              max_delta_step=None, max_depth=None,
#                                              max_leaves=None,
#                                              min_child_weight=None, missing=nan,
#                                              monotone_constraints=None,
#                                              multi_strategy=None,
#                                              n_estimators=None, n_jobs=None,
#                                              num_parallel_tree=None,
#                                              random_state=253, ...)),
#                                ('linear_regression', LinearRegression()),
#                                ('support_vector_machine', SVR())],
#                    final_estimator=LinearRegression()),
#  np.float64(-21.87632730303896))

# %%
results_df = pd.DataFrame(cv.cv_results_)
results_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.539831      0.068764         0.019078        0.000906
# 1       2.538151      0.072013         0.019607        0.000727
# 2       2.415246      0.185675         0.018886        0.002674
# 3       2.162863      0.067644         0.016551        0.003014
# 4       1.974725      0.267652         0.018620        0.003809
#
#                                param_final_estimator  \
# 0  DecisionTreeRegressor(criterion='absolute_erro...
# 1  ExtraTreesRegressor(criterion='absolute_error'...
# 2  XGBRegressor(base_score=None, booster=None, ca...
# 3                                 LinearRegression()
# 4                                              SVR()
#
#                                               params  \
# 0  {'final_estimator': DecisionTreeRegressor(crit...
# 1  {'final_estimator': ExtraTreesRegressor(criter...
# 2  {'final_estimator': XGBRegressor(base_score=No...
# 3            {'final_estimator': LinearRegression()}
# 4                         {'final_estimator': SVR()}
#
#    split0_test_neg_mean_squared_error  split1_test_neg_mean_squared_error  \
# 0                          -12.206691                          -22.255074
# 1                           -8.591727                          -18.427336
# 2                          -10.887093                          -40.318305
# 3                           -9.551364                          -12.216339
# 4                           -7.809763                          -38.443284
#
#    split2_test_neg_mean_squared_error  split3_test_neg_mean_squared_error  \
# 0                          -26.982921                          -58.925495
# 1                          -26.033492                          -57.059759
# 2                          -22.584728                          -64.108974
# 3                          -16.638173                          -51.576794
# 4                          -65.849931                          -55.111600
#
#    ...  mean_test_neg_mean_absolute_error  std_test_neg_mean_absolute_error  \
# 0  ...                          -3.580583                          0.603024
# 1  ...                          -3.238065                          0.671394
# 2  ...                          -4.346879                          1.523846
# 3  ...                          -3.061745                          0.574403
# 4  ...                          -3.867136                          0.954353
#
#    rank_test_neg_mean_absolute_error  split0_train_neg_mean_absolute_error  \
# 0                                  3                             -2.215842
# 1                                  2                             -2.061015
# 2                                  5                             -2.823397
# 3                                  1                             -2.165991
# 4                                  4                             -2.362217
#
#    split1_train_neg_mean_absolute_error  split2_train_neg_mean_absolute_error  \
# 0                             -2.051852                             -2.162469
# 1                             -1.750383                             -1.839185
# 2                             -3.203102                             -2.806305
# 3                             -1.263037                             -1.238091
# 4                             -2.345062                             -2.342889
#
#    split3_train_neg_mean_absolute_error  split4_train_neg_mean_absolute_error  \
# 0                             -1.992099                             -2.261111
# 1                             -1.653889                             -1.536988
# 2                             -2.277071                             -2.645488
# 3                             -1.260587                             -1.247118
# 4                             -1.990355                             -2.496124
#
#    mean_train_neg_mean_absolute_error  std_train_neg_mean_absolute_error
# 0                           -2.136674                           0.100513
# 1                           -1.768292                           0.177552
# 2                           -2.751073                           0.299479
# 3                           -1.434965                           0.365626
# 4                           -2.307329                           0.168414
#
# [5 rows x 36 columns]

# %%
results_df.iloc[cv.best_index_]
# Out:
# mean_fit_time                                                          2.162863
# std_fit_time                                                           0.067644
# mean_score_time                                                        0.016551
# std_score_time                                                         0.003014
# param_final_estimator                                        LinearRegression()
# params                                  {'final_estimator': LinearRegression()}
# split0_test_neg_mean_squared_error                                    -9.551364
# split1_test_neg_mean_squared_error                                   -12.216339
# split2_test_neg_mean_squared_error                                   -16.638173
# split3_test_neg_mean_squared_error                                   -51.576794
# split4_test_neg_mean_squared_error                                   -19.398966
# mean_test_neg_mean_squared_error                                     -21.876327
# std_test_neg_mean_squared_error                                       15.237542
# rank_test_neg_mean_squared_error                                              1
# split0_train_neg_mean_squared_error                                   -12.19571
# split1_train_neg_mean_squared_error                                   -5.091014
# split2_train_neg_mean_squared_error                                   -3.795325
# split3_train_neg_mean_squared_error                                   -3.073094
# split4_train_neg_mean_squared_error                                    -3.77783
# mean_train_neg_mean_squared_error                                     -5.586595
# std_train_neg_mean_squared_error                                       3.368203
# split0_test_neg_mean_absolute_error                                   -2.336091
# split1_test_neg_mean_absolute_error                                   -2.608741
# split2_test_neg_mean_absolute_error                                   -3.081897
# split3_test_neg_mean_absolute_error                                   -3.992021
# split4_test_neg_mean_absolute_error                                   -3.289973
# mean_test_neg_mean_absolute_error                                     -3.061745
# std_test_neg_mean_absolute_error                                       0.574403
# rank_test_neg_mean_absolute_error                                             1
# split0_train_neg_mean_absolute_error                                  -2.165991
# split1_train_neg_mean_absolute_error                                  -1.263037
# split2_train_neg_mean_absolute_error                                  -1.238091
# split3_train_neg_mean_absolute_error                                  -1.260587
# split4_train_neg_mean_absolute_error                                  -1.247118
# mean_train_neg_mean_absolute_error                                    -1.434965
# std_train_neg_mean_absolute_error                                      0.365626
# Name: 3, dtype: object

# %% [markdown]
# Okazuje się, że mimo wszystko model oparty wyłącznie o XGBoost jest najlepszy do przewidywania akurat tego zbioru danych.
